# %% [markdown]
# # Speech-to-Text from YouTube and ChatGPT Text Generation
#
# To convert audio file to text we use [OpenAI Whisper speech-to-text service](https://openai.com/research/whisper). For generative AI, we interfaced with GPT-3.5 or GPT-4 via [OpenAI API](https://platform.openai.com/docs/guides/gpt).

# %% [markdown]
# __It is recommended to run this Jyputer notebook on Google Colab cloud instead of local Python installation.__

# %% [markdown]
# ### Download audio track from YouTube video

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %%
if IN_COLAB:
    # !pip install git+https://github.com/openai/whisper.git
    # !nvidia-smi -L
    #!pip install pytube -q
    # !pip install pytube@git+https://github.com/OlekRomanko/pytube.git@master -q
    import whisper
    from pytube import YouTube
else:
    try:
        import whisper
    except:
        # !pip install openai-whisper
        import whisper
    try:
        from pytube import YouTube
    except:
        # !pip install pytube -q
        from pytube import YouTube
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-51qtt2se
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-51qtt2se
#   Resolved https://github.com/openai/whisper.git to commit e8622f9afc4eba139bf796c210f5c01081000472
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (2.0.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (4.66.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (10.1.0)
# Requirement already satisfied: tiktoken==0.3.3 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230314) (0.3.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.3.3->openai-whisper==20230314) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.3.3->openai-whisper==20230314) (2.31.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.12.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->openai-whisper==20230314) (16.0.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20230314) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20230314) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230314) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.3.3->openai-whisper==20230314) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20230314) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20230314) (1.3.0)
# GPU 0: Tesla T4 (UUID: GPU-13392fb6-3963-fc07-c22b-135c9f266882)
#   Preparing metadata (setup.py) ... done

# %%
model = whisper.load_model('base')

# %%
filename = "VisualPolitik_Silicon_Valley"

# %%
youtube_video_url = "youtube.com/watch?v=WNTtWYFhWus"

youtube_video = YouTube(youtube_video_url)

# %% [markdown]
# If from the next command you get `RegexMatchError: __init__: could not find match for ^\w+\W` error, as suggested on https://github.com/pytube/pytube/issues/1199, in order to solve the problem, you should go in the cipher.py file and replace the line 30, which is `var_regex = re.compile(r"^\w+\W")` with the line `var_regex = re.compile(r"^\$*\w+\W")`.

# %%
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
stream = streams.first()
stream
# Out:
# <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">

# %%
stream.download(filename=filename+'_audio.mp4')
# Out:
# '/content/VisualPolitik_Silicon_Valley_audio.mp4'

# %% [markdown]
# ### Convert audio to text (speech-to-text)

# %% [markdown]
# If from the next command you get an error similar to `FileNotFoundError: [WinError 2] The system cannot find the file specified`, install newest version of `ffmpeg` with `conda install conda-forge::ffmpeg` for your local Anaconda distribution.

# %%
#if not IN_COLAB:
#    try:
#        import ffmpeg
#    except:
#        !pip install ffmpeg-python
#        import ffmpeg

# %%
output = model.transcribe(filename+"_audio.mp4")

# %%
output
# Out:
# {'text': " This video has been made possible by Brilliant, a problem-solving based website and app with hands-on approach. Improve your STEM skills while having a great time learning at brilliant.org for a slasher visual politic EN. More on that in a bit. Here is the million dollar question in Europe. Why is there no European Google? Why does Europe seem to be an elephant's graveyard when it comes to business? To give you an idea of the five largest companies in the world, four are American and were launched after 1975. In Europe, however, it is common for the largest companies to have been started much earlier. Some, such as Nestle, date back to the 19th century, and even the pharmaceutical companies that created a giant like Novartis were started in the 17th and 18th centuries, no less. Let's see, credit where credit's due, these companies deserve a round of applause for having managed to survive in the market. But it's significant that no young European company is in this top five while in the 90's states, three of the five largest companies are younger than many of you watching this video. This indicates one thing. The USA is way ahead of Europe in terms of innovation. This does not mean that there are no companies in Europe that have not been innovative. SAP, which is a programme used by accountants in large companies, are Skype, which we all know, were conceived in Germany and Estonia. But they aren't much when compared to the United States. Until now, this was one more debate among many in Europe. But now, it is the most important debate that will be raised in the coming years. And that is because of the energy crisis. The current crisis is affecting all citizens with stratospheric electricity bills. But do you know who else is affected by these price increases? You guessed, if visual politics viewers, the companies, many of which may flee from a dying European Union, that no longer offers them low-cost gas. The European Union is no longer more competitive than the United States or China. In a few years' time, we could be talking about the European Union as a continental Detroit. In fact, as was the case in Detroit, the automotive industry is extremely important throughout Europe and not only in France and Germany. In Spain, for example, the automotive industry accounted for almost 8% of the entire GDP in 2020. In other words, the comparison with Detroit is no joke. And if you are a loyal follower to this channel, you will already know what it means to be Detroit, unemployment, slums and cranes. So how can this trend be changed? How could Europe move closer to the Silicon Valley model? Could the war in Ukraine revive the European Union? Today we're going to answer all these questions. But before we continue, whether you're trying to develop your professional skills or broaden your understanding of the world, we recommend checking out today's sponsor, Brilliant. Brilliant is a problem-solving based website and app with a hands-on approach. It's a better way to learn. They've got over 70 interactive courses in maths, science and computer science, and it doesn't matter whether you're a student looking to get ahead, or a professional keen on building new skills. You have to check out Brilliant. It's excellent. Maybe you've always wanted to learn about statistics, and trust me, statistics can be tricky and lead you to dubious conclusions. And no, just in case you were wondering, the fact that one out every five babies born on earth or Chinese does not mean that your fifth child will be Chinese. But jokes aside, there are lots of great stuff on their platform, including daily challenges which are a great way to flex our grey matter every day. So don't wait any longer, and let Brilliant help you master even complex technical subjects by clicking on the link below. You'll get started for free and hurry. The first 200 people get 20% off an annual premium subscription. And now, let's get cracking. History of Two Places A visual p ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 5.36,
#    'text': ' This video has been made possible by Brilliant, a problem-solving based website and app with hands-on approach.',
#    'tokens': [50364,
#     639,
#     960,
#     575,
#     668,
#     1027,
#     1944,
#     538,
#     34007,
#     11,
#     257,
#     1154,
#     12,
#     30926,
#     798,
#     2361,
#     3144,
#     293,
#     724,
#     365,
#     2377,
#     12,
#     266,
#     3109,
#     13,
#     50632],
#    'temperature': 0.0,
#    'avg_logprob': -0.34551248317811545,
#    'compression_ratio': 1.4734513274336283,
#    'no_speech_prob': 0.015368553809821606},
#   {'id': 1,
#    'seek': 0,
#    'start': 5.36,
#    'end': 8.64,
#    'text': ' Improve your STEM skills while having a great time learning at brilliant.org for',
#    'tokens': [50632,
#     46366,
#     428,
#     25043,
#     3942,
#     1339,
#     1419,
#     257,
#     869,
#     565,
#     2539,
#     412,
#     10248,
#     13,
#     4646,
#     337,
#     50796],
#    'temperature': 0.0,
#    'avg_logprob': -0.34551248317811545,
#    'compression_ratio': 1.4734513274336283,
#    'no_speech_prob': 0.015368553809821606},
#   {'id': 2,
#    'seek': 0,
#    'start': 8.64,
#    'end': 11.120000000000001,
#    'text': ' a slasher visual politic EN. More on that in a bit.',
#    'tokens': [50796,
#     257,
#     1061,
#     296,
#     511,
#     5056,
#     48044,
#     15244,
#     13,
#     5048,
#     322,
#     300,
#     294,
#     257,
#     857,
#     13,
#     50920],
#    'temperature': 0.0,
#    'avg_logprob': -0.34551248317811545,
#    'compression_ratio': 1.4734513274336283,
#    'no_speech_prob': 0.015368553809821606},
#   {'id': 3,
#    'seek': 0,
#    'start': 21.04,
#    'end': 24.8,
#    'text': ' Here is the million dollar question in Europe. Why is there no European Google? Why does',
#    'tokens': [51416,
#     1692,
#     307,
#     264,
#     2459,
#     7241,
#     1168,
#     294,
#     3315,
#     13,
#     1545,
#     307,
#     456,
#     572,
#     6473,
#     3329,
#     30,
#     1545,
#     775,
#     51604],
#    'temperature': 0.0,
#    'avg_logprob': -0.34551248317811545,
#    'compression_ratio': 1.4734513274336283,
#    'no_speech_prob': 0.015368553809821606},
#   {'id': 4,
#    'seek': 2480,
#    'start': 24.8,
#    'end': 27.6,
#    'text': " Europe seem to be an elephant's graveyard when it comes to business?",
#    'tokens': [50364,
#     3315,
#     1643,
#     281,
#     312,
#     364,
#     19791,
#     311,
#     42607,
#     562,
#     309,
#     1487,
#     281,
#     1606,
#     30,
#     50504],
#    'temperature': 0.0,
#    'avg_logprob': -0.12049691731693181,
#    'compression_ratio': 1.6882716049382716,
#    'no_speech_prob': 0.02397766523063183},
#   {'id': 5,
#    'seek': 2480,
#    'start': 31.200000000000003,
#    'end': 35.120000000000005,
#    'text': ' To give you an idea of the five largest companies in the world, four are American and were',
#    'tokens': [50684,
#     1407,
#     976,
#     291,
#     364,
#     1558,
#     295,
#     264,
#     1732,
#     6443,
#     3431,
#     294,
#     264,
#     1002,
#     11,
#     1451,
#     366,
#     2665,
#     293,
#     645,
#     50880],
#    'temperature': 0.0,
#    'avg_logprob': -0.12049691731693181,
#    'compression_ratio': 1.6882716049382716,
#    'no_speech_prob': 0.02397766523063183},
#   {'id': 6,
#    'seek': 2480,
#    'start': 35.120000000000005,
#    'end': 39.44,
#    'text': ' launched after 1975. In Europe, however, it is common for the largest companies to have been',
#    'tokens': [50880,
#     8730,
#     934,
#     32454,
#     13,
#     682,
#     3315,
#     11,
#     4461,
#     11,
#     309,
#     307,
#     2689,
#     337,
#     264,
#     6443,
#     3431,
#     281,
#     362,
#     668,
#     51096],
#    'temperature': 0.0,
#    'avg_logprob': -0.12049691731693181,
#    'compression_ratio': 1.6882716049382716,
#    'no_speech_prob': 0.02397766523063183},
#   {'id': 7,
#    'seek': 2480,
#    'start': 39.44,
#    'end': 44.0,
#    'text': ' started much earlier. Some, such as Nestle, date back to the 19th century, and even the pharmaceutical',
#    'tokens': [51096,
#     1409,
#     709,
#     3071,
#     13,
#     2188,
#     11,
#     1270,
#     382,
#     31581,
#     306,
#     11,
#     4002,
#     646,
#     281,
#     264,
#     1294,
#     392,
#     4901,
#     11,
#     293,
#     754,
#     264,
#     27130,
#     51324],
#    'temperature': 0.0,
#    'avg_logprob': -0.12049691731693181,
#    'compression_ratio': 1.6882716049382716,
#    'no_speech_prob': 0.02397766523063183},
#   {'id': 8,
#    'seek': 2480,
#    'start': 44.0,
#    'end': 48.480000000000004,
#    'text': ' companies that created a giant like Novartis were started in the 17th and 18th centuries, no less.',
#    'tokens': [51324,
#     3431,
#     300,
#     2942,
#     257,
#     7410,
#     411,
#     31948,
#     446,
#     271,
#     645,
#     1409,
#     294,
#     264,
#     3282,
#     392,
#     293,
#     2443,
#     392,
#     13926,
#     11,
#     572,
#     1570,
#     13,
#     51548],
#    'temperature': 0.0,
#    'avg_logprob': -0.12049691731693181,
#    'compression_ratio': 1.6882716049382716,
#    'no_speech_prob': 0.02397766523063183},
#   {'id': 9,
#    'seek': 2480,
#    'start': 50.480000000000004,
#    'end': 54.0,
#    'text': " Let's see, credit where credit's due, these companies deserve a round of applause for having",
#    'tokens': [51648,
#     961,
#     311,
#     536,
#     11,
#     5397,
#     689,
#     5397,
#     311,
#     3462,
#     11,
#     613,
#     3431,
#     9948,
#     257,
#     3098,
#     295,
#     9969,
#     337,
#     1419,
#     51824],
#    'temperature': 0.0,
#    'avg_logprob': -0.12049691731693181,
#    'compression_ratio': 1.6882716049382716,
#    'no_speech_prob': 0.02397766523063183},
#   {'id': 10,
#    'seek': 5400,
#    'start': 54.0,
#    'end': 57.36,
#    'text': " managed to survive in the market. But it's significant that no young European",
#    'tokens': [50364,
#     6453,
#     281,
#     7867,
#     294,
#     264,
#     2142,
#     13,
#     583,
#     309,
#     311,
#     4776,
#     300,
#     572,
#     2037,
#     6473,
#     50532],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 11,
#    'seek': 5400,
#    'start': 57.36,
#    'end': 61.12,
#    'text': " company is in this top five while in the 90's states, three of the five largest companies are",
#    'tokens': [50532,
#     2237,
#     307,
#     294,
#     341,
#     1192,
#     1732,
#     1339,
#     294,
#     264,
#     4289,
#     311,
#     4368,
#     11,
#     1045,
#     295,
#     264,
#     1732,
#     6443,
#     3431,
#     366,
#     50720],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 12,
#    'seek': 5400,
#    'start': 61.12,
#    'end': 66.0,
#    'text': ' younger than many of you watching this video. This indicates one thing. The USA is way ahead of',
#    'tokens': [50720,
#     7037,
#     813,
#     867,
#     295,
#     291,
#     1976,
#     341,
#     960,
#     13,
#     639,
#     16203,
#     472,
#     551,
#     13,
#     440,
#     10827,
#     307,
#     636,
#     2286,
#     295,
#     50964],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 13,
#    'seek': 5400,
#    'start': 66.0,
#    'end': 69.84,
#    'text': ' Europe in terms of innovation. This does not mean that there are no companies in Europe that have',
#    'tokens': [50964,
#     3315,
#     294,
#     2115,
#     295,
#     8504,
#     13,
#     639,
#     775,
#     406,
#     914,
#     300,
#     456,
#     366,
#     572,
#     3431,
#     294,
#     3315,
#     300,
#     362,
#     51156],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 14,
#    'seek': 5400,
#    'start': 69.84,
#    'end': 73.76,
#    'text': ' not been innovative. SAP, which is a programme used by accountants in large companies,',
#    'tokens': [51156,
#     406,
#     668,
#     12999,
#     13,
#     27743,
#     11,
#     597,
#     307,
#     257,
#     14001,
#     1143,
#     538,
#     2696,
#     1719,
#     294,
#     2416,
#     3431,
#     11,
#     51352],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 15,
#    'seek': 5400,
#    'start': 73.76,
#    'end': 78.24000000000001,
#    'text': " are Skype, which we all know, were conceived in Germany and Estonia. But they aren't much when",
#    'tokens': [51352,
#     366,
#     31743,
#     11,
#     597,
#     321,
#     439,
#     458,
#     11,
#     645,
#     34898,
#     294,
#     7244,
#     293,
#     4410,
#     16999,
#     13,
#     583,
#     436,
#     3212,
#     380,
#     709,
#     562,
#     51576],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 16,
#    'seek': 5400,
#    'start': 78.24000000000001,
#    'end': 83.03999999999999,
#    'text': ' compared to the United States. Until now, this was one more debate among many in Europe. But now,',
#    'tokens': [51576,
#     5347,
#     281,
#     264,
#     2824,
#     3040,
#     13,
#     9088,
#     586,
#     11,
#     341,
#     390,
#     472,
#     544,
#     7958,
#     3654,
#     867,
#     294,
#     3315,
#     13,
#     583,
#     586,
#     11,
#     51816],
#    'temperature': 0.0,
#    'avg_logprob': -0.1405382281855533,
#    'compression_ratio': 1.8016759776536313,
#    'no_speech_prob': 0.003535516792908311},
#   {'id': 17,
#    'seek': 8304,
#    'start': 83.12,
#    'end': 87.2,
#    'text': ' it is the most important debate that will be raised in the coming years. And that is because of the',
#    'tokens': [50368,
#     309,
#     307,
#     264,
#     881,
#     1021,
#     7958,
#     300,
#     486,
#     312,
#     6005,
#     294,
#     264,
#     1348,
#     924,
#     13,
#     400,
#     300,
#     307,
#     570,
#     295,
#     264,
#     50572],
#    'temperature': 0.0,
#    'avg_logprob': -0.14835626764814983,
#    'compression_ratio': 1.7164179104477613,
#    'no_speech_prob': 0.009698898531496525},
#   {'id': 18,
#    'seek': 8304,
#    'start': 87.2,
#    'end': 96.32000000000001,
#    'text': ' energy crisis. The current crisis is affecting all citizens with stratospheric electricity bills.',
#    'tokens': [50572,
#     2281,
#     5869,
#     13,
#     440,
#     2190,
#     5869,
#     307,
#     17476,
#     439,
#     7180,
#     365,
#     23674,
#     25145,
#     10356,
#     12433,
#     13,
#     51028],
#    'temperature': 0.0,
#    'avg_logprob': -0.14835626764814983,
#    'compression_ratio': 1.7164179104477613,
#    'no_speech_prob': 0.009698898531496525},
#   {'id': 19,
#    'seek': 8304,
#    'start': 96.32000000000001,
#    'end': 99.12,
#    'text': ' But do you know who else is affected by these price increases? You guessed, if visual',
#    'tokens': [51028,
#     583,
#     360,
#     291,
#     458,
#     567,
#     1646,
#     307,
#     8028,
#     538,
#     613,
#     3218,
#     8637,
#     30,
#     509,
#     21852,
#     11,
#     498,
#     5056,
#     51168],
#    'temperature': 0.0,
#    'avg_logprob': -0.14835626764814983,
#    'compression_ratio': 1.7164179104477613,
#    'no_speech_prob': 0.009698898531496525},
#   {'id': 20,
#    'seek': 8304,
#    'start': 99.12,
#    'end': 102.88000000000001,
#    'text': ' politics viewers, the companies, many of which may flee from a dying European Union, that no',
#    'tokens': [51168,
#     7341,
#     8499,
#     11,
#     264,
#     3431,
#     11,
#     867,
#     295,
#     597,
#     815,
#     25146,
#     490,
#     257,
#     8639,
#     6473,
#     8133,
#     11,
#     300,
#     572,
#     51356],
#    'temperature': 0.0,
#    'avg_logprob': -0.14835626764814983,
#    'compression_ratio': 1.7164179104477613,
#    'no_speech_prob': 0.009698898531496525},
#   {'id': 21,
#    'seek': 8304,
#    'start': 102.88000000000001,
#    'end': 106.96000000000001,
#    'text': ' longer offers them low-cost gas. The European Union is no longer more competitive than the United',
#    'tokens': [51356,
#     2854,
#     7736,
#     552,
#     2295,
#     12,
#     27718,
#     4211,
#     13,
#     440,
#     6473,
#     8133,
#     307,
#     572,
#     2854,
#     544,
#     10043,
#     813,
#     264,
#     2824,
#     51560],
#    'temperature': 0.0,
#    'avg_logprob': -0.14835626764814983,
#    'compression_ratio': 1.7164179104477613,
#    'no_speech_prob': 0.009698898531496525},
#   {'id': 22,
#    'seek': 8304,
#    'start': 106.96000000000001,
#    'end': 111.04,
#    'text': " States or China. In a few years' time, we could be talking about the European Union as a continental",
#    'tokens': [51560,
#     3040,
#     420,
#     3533,
#     13,
#     682,
#     257,
#     1326,
#     924,
#     6,
#     565,
#     11,
#     321,
#     727,
#     312,
#     1417,
#     466,
#     264,
#     6473,
#     8133,
#     382,
#     257,
#     42479,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.14835626764814983,
#    'compression_ratio': 1.7164179104477613,
#    'no_speech_prob': 0.009698898531496525},
#   {'id': 23,
#    'seek': 11104,
#    'start': 111.68,
#    'end': 115.44000000000001,
#    'text': ' Detroit. In fact, as was the case in Detroit, the automotive industry is extremely important',
#    'tokens': [50396,
#     20887,
#     13,
#     682,
#     1186,
#     11,
#     382,
#     390,
#     264,
#     1389,
#     294,
#     20887,
#     11,
#     264,
#     32866,
#     3518,
#     307,
#     4664,
#     1021,
#     50584],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 24,
#    'seek': 11104,
#    'start': 115.44000000000001,
#    'end': 119.2,
#    'text': ' throughout Europe and not only in France and Germany. In Spain, for example, the automotive',
#    'tokens': [50584,
#     3710,
#     3315,
#     293,
#     406,
#     787,
#     294,
#     6190,
#     293,
#     7244,
#     13,
#     682,
#     12838,
#     11,
#     337,
#     1365,
#     11,
#     264,
#     32866,
#     50772],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 25,
#    'seek': 11104,
#    'start': 119.2,
#    'end': 124.24000000000001,
#    'text': ' industry accounted for almost 8% of the entire GDP in 2020. In other words, the comparison with',
#    'tokens': [50772,
#     3518,
#     43138,
#     337,
#     1920,
#     1649,
#     4,
#     295,
#     264,
#     2302,
#     19599,
#     294,
#     4808,
#     13,
#     682,
#     661,
#     2283,
#     11,
#     264,
#     9660,
#     365,
#     51024],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 26,
#    'seek': 11104,
#    'start': 124.24000000000001,
#    'end': 128.24,
#    'text': ' Detroit is no joke. And if you are a loyal follower to this channel, you will already know what it',
#    'tokens': [51024,
#     20887,
#     307,
#     572,
#     7647,
#     13,
#     400,
#     498,
#     291,
#     366,
#     257,
#     12682,
#     35413,
#     281,
#     341,
#     2269,
#     11,
#     291,
#     486,
#     1217,
#     458,
#     437,
#     309,
#     51224],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 27,
#    'seek': 11104,
#    'start': 128.24,
#    'end': 132.56,
#    'text': ' means to be Detroit, unemployment, slums and cranes. So how can this trend be changed? How could',
#    'tokens': [51224,
#     1355,
#     281,
#     312,
#     20887,
#     11,
#     17438,
#     11,
#     1061,
#     8099,
#     293,
#     941,
#     12779,
#     13,
#     407,
#     577,
#     393,
#     341,
#     6028,
#     312,
#     3105,
#     30,
#     1012,
#     727,
#     51440],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 28,
#    'seek': 11104,
#    'start': 132.56,
#    'end': 136.72,
#    'text': ' Europe move closer to the Silicon Valley model? Could the war in Ukraine revive the European Union?',
#    'tokens': [51440,
#     3315,
#     1286,
#     4966,
#     281,
#     264,
#     25351,
#     10666,
#     2316,
#     30,
#     7497,
#     264,
#     1516,
#     294,
#     14081,
#     36292,
#     264,
#     6473,
#     8133,
#     30,
#     51648],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 29,
#    'seek': 11104,
#    'start': 136.72,
#    'end': 140.0,
#    'text': " Today we're going to answer all these questions. But before we continue, whether you're trying to",
#    'tokens': [51648,
#     2692,
#     321,
#     434,
#     516,
#     281,
#     1867,
#     439,
#     613,
#     1651,
#     13,
#     583,
#     949,
#     321,
#     2354,
#     11,
#     1968,
#     291,
#     434,
#     1382,
#     281,
#     51812],
#    'temperature': 0.0,
#    'avg_logprob': -0.11647405379857773,
#    'compression_ratio': 1.6766169154228856,
#    'no_speech_prob': 0.021268947049975395},
#   {'id': 30,
#    'seek': 14000,
#    'start': 140.0,
#    'end': 143.6,
#    'text': ' develop your professional skills or broaden your understanding of the world, we recommend checking',
#    'tokens': [50364,
#     1499,
#     428,
#     4843,
#     3942,
#     420,
#     47045,
#     428,
#     3701,
#     295,
#     264,
#     1002,
#     11,
#     321,
#     2748,
#     8568,
#     50544],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 31,
#    'seek': 14000,
#    'start': 143.6,
#    'end': 147.84,
#    'text': " out today's sponsor, Brilliant. Brilliant is a problem-solving based website and app with a",
#    'tokens': [50544,
#     484,
#     965,
#     311,
#     16198,
#     11,
#     34007,
#     13,
#     34007,
#     307,
#     257,
#     1154,
#     12,
#     30926,
#     798,
#     2361,
#     3144,
#     293,
#     724,
#     365,
#     257,
#     50756],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 32,
#    'seek': 14000,
#    'start': 147.84,
#    'end': 152.16,
#    'text': " hands-on approach. It's a better way to learn. They've got over 70 interactive courses in maths,",
#    'tokens': [50756,
#     2377,
#     12,
#     266,
#     3109,
#     13,
#     467,
#     311,
#     257,
#     1101,
#     636,
#     281,
#     1466,
#     13,
#     814,
#     600,
#     658,
#     670,
#     5285,
#     15141,
#     7712,
#     294,
#     36287,
#     11,
#     50972],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 33,
#    'seek': 14000,
#    'start': 152.16,
#    'end': 155.2,
#    'text': " science and computer science, and it doesn't matter whether you're a student looking to get ahead,",
#    'tokens': [50972,
#     3497,
#     293,
#     3820,
#     3497,
#     11,
#     293,
#     309,
#     1177,
#     380,
#     1871,
#     1968,
#     291,
#     434,
#     257,
#     3107,
#     1237,
#     281,
#     483,
#     2286,
#     11,
#     51124],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 34,
#    'seek': 14000,
#    'start': 155.2,
#    'end': 159.28,
#    'text': " or a professional keen on building new skills. You have to check out Brilliant. It's excellent.",
#    'tokens': [51124,
#     420,
#     257,
#     4843,
#     20297,
#     322,
#     2390,
#     777,
#     3942,
#     13,
#     509,
#     362,
#     281,
#     1520,
#     484,
#     34007,
#     13,
#     467,
#     311,
#     7103,
#     13,
#     51328],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 35,
#    'seek': 14000,
#    'start': 159.28,
#    'end': 163.36,
#    'text': " Maybe you've always wanted to learn about statistics, and trust me, statistics can be tricky and",
#    'tokens': [51328,
#     2704,
#     291,
#     600,
#     1009,
#     1415,
#     281,
#     1466,
#     466,
#     12523,
#     11,
#     293,
#     3361,
#     385,
#     11,
#     12523,
#     393,
#     312,
#     12414,
#     293,
#     51532],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 36,
#    'seek': 14000,
#    'start': 163.36,
#    'end': 167.12,
#    'text': ' lead you to dubious conclusions. And no, just in case you were wondering, the fact that one out',
#    'tokens': [51532,
#     1477,
#     291,
#     281,
#     18540,
#     851,
#     22865,
#     13,
#     400,
#     572,
#     11,
#     445,
#     294,
#     1389,
#     291,
#     645,
#     6359,
#     11,
#     264,
#     1186,
#     300,
#     472,
#     484,
#     51720],
#    'temperature': 0.0,
#    'avg_logprob': -0.09726221023067351,
#    'compression_ratio': 1.7263427109974425,
#    'no_speech_prob': 0.007692675571888685},
#   {'id': 37,
#    'seek': 16712,
#    'start': 167.12,
#    'end': 172.0,
#    'text': ' every five babies born on earth or Chinese does not mean that your fifth child will be Chinese.',
#    'tokens': [50364,
#     633,
#     1732,
#     10917,
#     4232,
#     322,
#     4120,
#     420,
#     4649,
#     775,
#     406,
#     914,
#     300,
#     428,
#     9266,
#     1440,
#     486,
#     312,
#     4649,
#     13,
#     50608],
#    'temperature': 0.0,
#    'avg_logprob': -0.12454670125787909,
#    'compression_ratio': 1.5667752442996743,
#    'no_speech_prob': 0.007813059724867344},
#   {'id': 38,
#    'seek': 16712,
#    'start': 172.0,
#    'end': 175.84,
#    'text': ' But jokes aside, there are lots of great stuff on their platform, including daily challenges',
#    'tokens': [50608,
#     583,
#     14439,
#     7359,
#     11,
#     456,
#     366,
#     3195,
#     295,
#     869,
#     1507,
#     322,
#     641,
#     3663,
#     11,
#     3009,
#     5212,
#     4759,
#     50800],
#    'temperature': 0.0,
#    'avg_logprob': -0.12454670125787909,
#    'compression_ratio': 1.5667752442996743,
#    'no_speech_prob': 0.007813059724867344},
#   {'id': 39,
#    'seek': 16712,
#    'start': 175.84,
#    'end': 180.32,
#    'text': " which are a great way to flex our grey matter every day. So don't wait any longer, and let Brilliant",
#    'tokens': [50800,
#     597,
#     366,
#     257,
#     869,
#     636,
#     281,
#     5896,
#     527,
#     16578,
#     1871,
#     633,
#     786,
#     13,
#     407,
#     500,
#     380,
#     1699,
#     604,
#     2854,
#     11,
#     293,
#     718,
#     34007,
#     51024],
#    'temperature': 0.0,
#    'avg_logprob': -0.12454670125787909,
#    'compression_ratio': 1.5667752442996743,
#    'no_speech_prob': 0.007813059724867344},
#   {'id': 40,
#    'seek': 16712,
#    'start': 180.32,
#    'end': 184.16,
#    'text': " help you master even complex technical subjects by clicking on the link below. You'll get started",
#    'tokens': [51024,
#     854,
#     291,
#     4505,
#     754,
#     3997,
#     6191,
#     13066,
#     538,
#     9697,
#     322,
#     264,
#     2113,
#     2507,
#     13,
#     509,
#     603,
#     483,
#     1409,
#     51216],
#    'temperature': 0.0,
#    'avg_logprob': -0.12454670125787909,
#    'compression_ratio': 1.5667752442996743,
#    'no_speech_prob': 0.007813059724867344},
#   {'id': 41,
#    'seek': 16712,
#    'start': 184.16,
#    'end': 189.36,
#    'text': ' for free and hurry. The first 200 people get 20% off an annual premium subscription. And now,',
#    'tokens': [51216,
#     337,
#     1737,
#     293,
#     11025,
#     13,
#     440,
#     700,
#     2331,
#     561,
#     483,
#     945,
#     4,
#     766,
#     364,
#     9784,
#     12049,
#     17231,
#     13,
#     400,
#     586,
#     11,
#     51476],
#    'temperature': 0.0,
#    'avg_logprob': -0.12454670125787909,
#    'compression_ratio': 1.5667752442996743,
#    'no_speech_prob': 0.007813059724867344},
#   {'id': 42,
#    'seek': 18936,
#    'start': 189.44000000000003,
#    'end': 190.16000000000003,
#    'text': " let's get cracking.",
#    'tokens': [50368, 718, 311, 483, 25229, 13, 50404],
#    'temperature': 0.0,
#    'avg_logprob': -0.16071109943561726,
#    'compression_ratio': 1.5220588235294117,
#    'no_speech_prob': 0.013626047410070896},
#   {'id': 43,
#    'seek': 18936,
#    'start': 194.88000000000002,
#    'end': 196.56,
#    'text': ' History of Two Places',
#    'tokens': [50640, 12486, 295, 4453, 2149, 2116, 50724],
#    'temperature': 0.0,
#    'avg_logprob': -0.16071109943561726,
#    'compression_ratio': 1.5220588235294117,
#    'no_speech_prob': 0.013626047410070896},
#   {'id': 44,
#    'seek': 18936,
#    'start': 200.32000000000002,
#    'end': 204.48000000000002,
#    'text': " A visual politic had existed in the 1950s, there would be two places we'd be talking about nonstop.",
#    'tokens': [50912,
#     316,
#     5056,
#     48044,
#     632,
#     13135,
#     294,
#     264,
#     18141,
#     82,
#     11,
#     456,
#     576,
#     312,
#     732,
#     3190,
#     321,
#     1116,
#     312,
#     1417,
#     466,
#     2107,
#     13559,
#     13,
#     51120],
#    'temperature': 0.0,
#    'avg_logprob': -0.16071109943561726,
#    'compression_ratio': 1.5220588235294117,
#    'no_speech_prob': 0.013626047410070896},
#   {'id': 45,
#    'seek': 18936,
#    'start': 204.48000000000002,
#    'end': 208.4,
#    'text': ' Silicon Valley and Detroit. And you may be wondering, what do you mean Detroit? Well, yes,',
#    'tokens': [51120,
#     25351,
#     10666,
#     293,
#     20887,
#     13,
#     400,
#     291,
#     815,
#     312,
#     6359,
#     11,
#     437,
#     360,
#     291,
#     914,
#     20887,
#     30,
#     1042,
#     11,
#     2086,
#     11,
#     51316],
#    'temperature': 0.0,
#    'avg_logprob': -0.16071109943561726,
#    'compression_ratio': 1.5220588235294117,
#    'no_speech_prob': 0.013626047410070896},
#   {'id': 46,
#    'seek': 18936,
#    'start': 208.4,
#    'end': 212.24,
#    'text': ' in the 1950s, Detroit was mainly home to a large automobile industry with a well-known',
#    'tokens': [51316,
#     294,
#     264,
#     18141,
#     82,
#     11,
#     20887,
#     390,
#     8704,
#     1280,
#     281,
#     257,
#     2416,
#     38809,
#     3518,
#     365,
#     257,
#     731,
#     12,
#     6861,
#     51508],
#    'temperature': 0.0,
#    'avg_logprob': -0.16071109943561726,
#    'compression_ratio': 1.5220588235294117,
#    'no_speech_prob': 0.013626047410070896},
#   {'id': 47,
#    'seek': 18936,
#    'start': 212.24,
#    'end': 215.84,
#    'text': ' brand such as Ford and Chevrolet. In fact, a lot of people started to move there, just as they',
#    'tokens': [51508,
#     3360,
#     1270,
#     382,
#     11961,
#     293,
#     44236,
#     340,
#     2631,
#     13,
#     682,
#     1186,
#     11,
#     257,
#     688,
#     295,
#     561,
#     1409,
#     281,
#     1286,
#     456,
#     11,
#     445,
#     382,
#     436,
#     51688],
#    'temperature': 0.0,
#    'avg_logprob': -0.16071109943561726,
#    'compression_ratio': 1.5220588235294117,
#    'no_speech_prob': 0.013626047410070896},
#   {'id': 48,
#    'seek': 21584,
#    'start': 215.84,
#    'end': 219.84,
#    'text': ' stood to Silicon Valley, with the population reaching almost two million people. Meanwhile,',
#    'tokens': [50364,
#     9371,
#     281,
#     25351,
#     10666,
#     11,
#     365,
#     264,
#     4415,
#     9906,
#     1920,
#     732,
#     2459,
#     561,
#     13,
#     13879,
#     11,
#     50564],
#    'temperature': 0.0,
#    'avg_logprob': -0.12231462860107421,
#    'compression_ratio': 1.6231003039513678,
#    'no_speech_prob': 0.003480809973552823},
#   {'id': 49,
#    'seek': 21584,
#    'start': 219.84,
#    'end': 223.84,
#    'text': ' the other successful sister city in the United States from 1950s onwards was, and still is,',
#    'tokens': [50564,
#     264,
#     661,
#     4406,
#     4892,
#     2307,
#     294,
#     264,
#     2824,
#     3040,
#     490,
#     18141,
#     82,
#     34230,
#     390,
#     11,
#     293,
#     920,
#     307,
#     11,
#     50764],
#    'temperature': 0.0,
#    'avg_logprob': -0.12231462860107421,
#    'compression_ratio': 1.6231003039513678,
#    'no_speech_prob': 0.003480809973552823},
#   {'id': 50,
#    'seek': 21584,
#    'start': 223.84,
#    'end': 227.28,
#    'text': ' Silicon Valley. Can you tell me where the initial success of this valley was to be found?',
#    'tokens': [50764,
#     25351,
#     10666,
#     13,
#     1664,
#     291,
#     980,
#     385,
#     689,
#     264,
#     5883,
#     2245,
#     295,
#     341,
#     17636,
#     390,
#     281,
#     312,
#     1352,
#     30,
#     50936],
#    'temperature': 0.0,
#    'avg_logprob': -0.12231462860107421,
#    'compression_ratio': 1.6231003039513678,
#    'no_speech_prob': 0.003480809973552823},
#   {'id': 51,
#    'seek': 21584,
#    'start': 227.28,
#    'end': 230.4,
#    'text': " Well, for those of you who don't know, it was no less than, in the war.",
#    'tokens': [50936,
#     1042,
#     11,
#     337,
#     729,
#     295,
#     291,
#     567,
#     500,
#     380,
#     458,
#     11,
#     309,
#     390,
#     572,
#     1570,
#     813,
#     11,
#     294,
#     264,
#     1516,
#     13,
#     51092],
#    'temperature': 0.0,
#    'avg_logprob': -0.12231462860107421,
#    'compression_ratio': 1.6231003039513678,
#    'no_speech_prob': 0.003480809973552823},
#   {'id': 52,
#    'seek': 21584,
#    'start': 233.6,
#    'end': 237.6,
#    'text': ' You heard correctly. During World War II, the United States was focused on fighting Japan in the',
#    'tokens': [51252,
#     509,
#     2198,
#     8944,
#     13,
#     6842,
#     3937,
#     3630,
#     6351,
#     11,
#     264,
#     2824,
#     3040,
#     390,
#     5178,
#     322,
#     5237,
#     3367,
#     294,
#     264,
#     51452],
#    'temperature': 0.0,
#    'avg_logprob': -0.12231462860107421,
#    'compression_ratio': 1.6231003039513678,
#    'no_speech_prob': 0.003480809973552823},
#   {'id': 53,
#    'seek': 21584,
#    'start': 237.6,
#    'end': 241.6,
#    'text': ' Pacific. So California started getting a lot of investment and workers to open all kinds of',
#    'tokens': [51452,
#     13335,
#     13,
#     407,
#     5384,
#     1409,
#     1242,
#     257,
#     688,
#     295,
#     6078,
#     293,
#     5600,
#     281,
#     1269,
#     439,
#     3685,
#     295,
#     51652],
#    'temperature': 0.0,
#    'avg_logprob': -0.12231462860107421,
#    'compression_ratio': 1.6231003039513678,
#    'no_speech_prob': 0.003480809973552823},
#   {'id': 54,
#    'seek': 24160,
#    'start': 241.6,
#    'end': 246.16,
#    'text': ' factories and businesses who supply the military effort. So you could say that Silicon Valley was',
#    'tokens': [50364,
#     24813,
#     293,
#     6011,
#     567,
#     5847,
#     264,
#     4632,
#     4630,
#     13,
#     407,
#     291,
#     727,
#     584,
#     300,
#     25351,
#     10666,
#     390,
#     50592],
#    'temperature': 0.0,
#    'avg_logprob': -0.11525641632080078,
#    'compression_ratio': 1.698224852071006,
#    'no_speech_prob': 0.0005274497671052814},
#   {'id': 55,
#    'seek': 24160,
#    'start': 246.16,
#    'end': 249.84,
#    'text': ' in the right place at the right time. Not only was it located in California, but it also had a',
#    'tokens': [50592,
#     294,
#     264,
#     558,
#     1081,
#     412,
#     264,
#     558,
#     565,
#     13,
#     1726,
#     787,
#     390,
#     309,
#     6870,
#     294,
#     5384,
#     11,
#     457,
#     309,
#     611,
#     632,
#     257,
#     50776],
#    'temperature': 0.0,
#    'avg_logprob': -0.11525641632080078,
#    'compression_ratio': 1.698224852071006,
#    'no_speech_prob': 0.0005274497671052814},
#   {'id': 56,
#    'seek': 24160,
#    'start': 249.84,
#    'end': 254.56,
#    'text': ' large university community in Palo Alto, and therefore highly qualified professionals. And,',
#    'tokens': [50776,
#     2416,
#     5454,
#     1768,
#     294,
#     6116,
#     78,
#     50066,
#     11,
#     293,
#     4412,
#     5405,
#     15904,
#     11954,
#     13,
#     400,
#     11,
#     51012],
#    'temperature': 0.0,
#    'avg_logprob': -0.11525641632080078,
#    'compression_ratio': 1.698224852071006,
#    'no_speech_prob': 0.0005274497671052814},
#   {'id': 57,
#    'seek': 24160,
#    'start': 254.56,
#    'end': 258.88,
#    'text': ' as war not only demanded commodities, but also technologies that were very advanced for the time,',
#    'tokens': [51012,
#     382,
#     1516,
#     406,
#     787,
#     28276,
#     40777,
#     11,
#     457,
#     611,
#     7943,
#     300,
#     645,
#     588,
#     7339,
#     337,
#     264,
#     565,
#     11,
#     51228],
#    'temperature': 0.0,
#    'avg_logprob': -0.11525641632080078,
#    'compression_ratio': 1.698224852071006,
#    'no_speech_prob': 0.0005274497671052814},
#   {'id': 58,
#    'seek': 24160,
#    'start': 258.88,
#    'end': 263.68,
#    'text': ' suddenly, this place started to take off. For example, many, many companies began to develop',
#    'tokens': [51228,
#     5800,
#     11,
#     341,
#     1081,
#     1409,
#     281,
#     747,
#     766,
#     13,
#     1171,
#     1365,
#     11,
#     867,
#     11,
#     867,
#     3431,
#     4283,
#     281,
#     1499,
#     51468],
#    'temperature': 0.0,
#    'avg_logprob': -0.11525641632080078,
#    'compression_ratio': 1.698224852071006,
#    'no_speech_prob': 0.0005274497671052814},
#   {'id': 59,
#    'seek': 24160,
#    'start': 263.68,
#    'end': 267.52,
#    'text': ' new semiconductors for bombs here. And so what would later become known as Silicon Valley became a',
#    'tokens': [51468,
#     777,
#     36924,
#     5547,
#     337,
#     19043,
#     510,
#     13,
#     400,
#     370,
#     437,
#     576,
#     1780,
#     1813,
#     2570,
#     382,
#     25351,
#     10666,
#     3062,
#     257,
#     51660],
#    'temperature': 0.0,
#    'avg_logprob': -0.11525641632080078,
#    'compression_ratio': 1.698224852071006,
#    'no_speech_prob': 0.0005274497671052814},
#   {'id': 60,
#    'seek': 26752,
#    'start': 267.59999999999997,
#    'end': 276.47999999999996,
#    'text': ' key player during the war. But that seed soon sprouted, because Silicon Valley was a particularly',
#    'tokens': [50368,
#     2141,
#     4256,
#     1830,
#     264,
#     1516,
#     13,
#     583,
#     300,
#     8871,
#     2321,
#     43728,
#     292,
#     11,
#     570,
#     25351,
#     10666,
#     390,
#     257,
#     4098,
#     50812],
#    'temperature': 0.0,
#    'avg_logprob': -0.14426686213566706,
#    'compression_ratio': 1.6330935251798562,
#    'no_speech_prob': 0.0020490812603384256},
#   {'id': 61,
#    'seek': 26752,
#    'start': 276.47999999999996,
#    'end': 280.47999999999996,
#    'text': ' fertile ground for companies. And one of those responsible for this entrepreneurial fertility was',
#    'tokens': [50812,
#     43509,
#     2727,
#     337,
#     3431,
#     13,
#     400,
#     472,
#     295,
#     729,
#     6250,
#     337,
#     341,
#     33094,
#     31707,
#     390,
#     51012],
#    'temperature': 0.0,
#    'avg_logprob': -0.14426686213566706,
#    'compression_ratio': 1.6330935251798562,
#    'no_speech_prob': 0.0020490812603384256},
#   {'id': 62,
#    'seek': 26752,
#    'start': 280.47999999999996,
#    'end': 287.84,
#    'text': ' the man you see on the screen right now. We are talking about Professor Frederick',
#    'tokens': [51012,
#     264,
#     587,
#     291,
#     536,
#     322,
#     264,
#     2568,
#     558,
#     586,
#     13,
#     492,
#     366,
#     1417,
#     466,
#     8419,
#     35617,
#     51380],
#    'temperature': 0.0,
#    'avg_logprob': -0.14426686213566706,
#    'compression_ratio': 1.6330935251798562,
#    'no_speech_prob': 0.0020490812603384256},
#   {'id': 63,
#    'seek': 26752,
#    'start': 287.84,
#    'end': 291.35999999999996,
#    'text': ' Terman, the father of the connection between universities and private enterprise.',
#    'tokens': [51380,
#     314,
#     11821,
#     11,
#     264,
#     3086,
#     295,
#     264,
#     4984,
#     1296,
#     11779,
#     293,
#     4551,
#     14132,
#     13,
#     51556],
#    'temperature': 0.0,
#    'avg_logprob': -0.14426686213566706,
#    'compression_ratio': 1.6330935251798562,
#    'no_speech_prob': 0.0020490812603384256},
#   {'id': 64,
#    'seek': 26752,
#    'start': 291.35999999999996,
#    'end': 294.96,
#    'text': ' Terman understood that universities produce knowledge, but it is the entrepreneurs who convert',
#    'tokens': [51556,
#     314,
#     11821,
#     7320,
#     300,
#     11779,
#     5258,
#     3601,
#     11,
#     457,
#     309,
#     307,
#     264,
#     12639,
#     567,
#     7620,
#     51736],
#    'temperature': 0.0,
#    'avg_logprob': -0.14426686213566706,
#    'compression_ratio': 1.6330935251798562,
#    'no_speech_prob': 0.0020490812603384256},
#   {'id': 65,
#    'seek': 29496,
#    'start': 294.96,
#    'end': 299.03999999999996,
#    'text': ' this development into innovation. That is, into products that are useful to society. With this',
#    'tokens': [50364,
#     341,
#     3250,
#     666,
#     8504,
#     13,
#     663,
#     307,
#     11,
#     666,
#     3383,
#     300,
#     366,
#     4420,
#     281,
#     4086,
#     13,
#     2022,
#     341,
#     50568],
#    'temperature': 0.0,
#    'avg_logprob': -0.09183908277942289,
#    'compression_ratio': 1.83596214511041,
#    'no_speech_prob': 0.005136112216860056},
#   {'id': 66,
#    'seek': 29496,
#    'start': 299.03999999999996,
#    'end': 303.2,
#    'text': ' idea in mind, he worked tirelessly to open the university to companies and strengthen ties with',
#    'tokens': [50568,
#     1558,
#     294,
#     1575,
#     11,
#     415,
#     2732,
#     11756,
#     12048,
#     281,
#     1269,
#     264,
#     5454,
#     281,
#     3431,
#     293,
#     17045,
#     14039,
#     365,
#     50776],
#    'temperature': 0.0,
#    'avg_logprob': -0.09183908277942289,
#    'compression_ratio': 1.83596214511041,
#    'no_speech_prob': 0.005136112216860056},
#   {'id': 67,
#    'seek': 29496,
#    'start': 303.2,
#    'end': 307.44,
#    'text': " them. In line with his vision, companies would finance and promote the university's research projects,",
#    'tokens': [50776,
#     552,
#     13,
#     682,
#     1622,
#     365,
#     702,
#     5201,
#     11,
#     3431,
#     576,
#     10719,
#     293,
#     9773,
#     264,
#     5454,
#     311,
#     2132,
#     4455,
#     11,
#     50988],
#    'temperature': 0.0,
#    'avg_logprob': -0.09183908277942289,
#    'compression_ratio': 1.83596214511041,
#    'no_speech_prob': 0.005136112216860056},
#   {'id': 68,
#    'seek': 29496,
#    'start': 307.44,
#    'end': 311.91999999999996,
#    'text': ' which would give the university many more resources and a guide of where to go. On the other hand,',
#    'tokens': [50988,
#     597,
#     576,
#     976,
#     264,
#     5454,
#     867,
#     544,
#     3593,
#     293,
#     257,
#     5934,
#     295,
#     689,
#     281,
#     352,
#     13,
#     1282,
#     264,
#     661,
#     1011,
#     11,
#     51212],
#    'temperature': 0.0,
#    'avg_logprob': -0.09183908277942289,
#    'compression_ratio': 1.83596214511041,
#    'no_speech_prob': 0.005136112216860056},
#   {'id': 69,
#    'seek': 29496,
#    'start': 311.91999999999996,
#    'end': 315.52,
#    'text': ' collaboration with the university would allow companies to grow faster, and therefore,',
#    'tokens': [51212,
#     9363,
#     365,
#     264,
#     5454,
#     576,
#     2089,
#     3431,
#     281,
#     1852,
#     4663,
#     11,
#     293,
#     4412,
#     11,
#     51392],
#    'temperature': 0.0,
#    'avg_logprob': -0.09183908277942289,
#    'compression_ratio': 1.83596214511041,
#    'no_speech_prob': 0.005136112216860056},
#   {'id': 70,
#    'seek': 29496,
#    'start': 315.52,
#    'end': 320.0,
#    'text': ' eventually have more resources. And so the cycle continued. However, in order to get the whole process',
#    'tokens': [51392,
#     4728,
#     362,
#     544,
#     3593,
#     13,
#     400,
#     370,
#     264,
#     6586,
#     7014,
#     13,
#     2908,
#     11,
#     294,
#     1668,
#     281,
#     483,
#     264,
#     1379,
#     1399,
#     51616],
#    'temperature': 0.0,
#    'avg_logprob': -0.09183908277942289,
#    'compression_ratio': 1.83596214511041,
#    'no_speech_prob': 0.005136112216860056},
#   {'id': 71,
#    'seek': 32000,
#    'start': 320.0,
#    'end': 324.32,
#    'text': ' started, we are still missing a key factor, something that entrepreneurs desperately need.',
#    'tokens': [50364,
#     1409,
#     11,
#     321,
#     366,
#     920,
#     5361,
#     257,
#     2141,
#     5952,
#     11,
#     746,
#     300,
#     12639,
#     23726,
#     643,
#     13,
#     50580],
#    'temperature': 0.0,
#    'avg_logprob': -0.13327377492731268,
#    'compression_ratio': 1.7031802120141342,
#    'no_speech_prob': 0.016911162063479424},
#   {'id': 72,
#    'seek': 32000,
#    'start': 327.36,
#    'end': 331.92,
#    'text': ' So, the million dollar question is, what could it be that these entrepreneurs needed funding?',
#    'tokens': [50732,
#     407,
#     11,
#     264,
#     2459,
#     7241,
#     1168,
#     307,
#     11,
#     437,
#     727,
#     309,
#     312,
#     300,
#     613,
#     12639,
#     2978,
#     6137,
#     30,
#     50960],
#    'temperature': 0.0,
#    'avg_logprob': -0.13327377492731268,
#    'compression_ratio': 1.7031802120141342,
#    'no_speech_prob': 0.016911162063479424},
#   {'id': 73,
#    'seek': 32000,
#    'start': 331.92,
#    'end': 334.88,
#    'text': " And that's where this other gentleman you see on the screen stepped in.",
#    'tokens': [50960,
#     400,
#     300,
#     311,
#     689,
#     341,
#     661,
#     15761,
#     291,
#     536,
#     322,
#     264,
#     2568,
#     15251,
#     294,
#     13,
#     51108],
#    'temperature': 0.0,
#    'avg_logprob': -0.13327377492731268,
#    'compression_ratio': 1.7031802120141342,
#    'no_speech_prob': 0.016911162063479424},
#   {'id': 74,
#    'seek': 32000,
#    'start': 334.88,
#    'end': 338.64,
#    'text': " Lawrence Rockefeller, the creator of Silicon Valley's first venture capital fund,",
#    'tokens': [51108,
#     22787,
#     50178,
#     14983,
#     11,
#     264,
#     14181,
#     295,
#     25351,
#     10666,
#     311,
#     700,
#     18474,
#     4238,
#     2374,
#     11,
#     51296],
#    'temperature': 0.0,
#    'avg_logprob': -0.13327377492731268,
#    'compression_ratio': 1.7031802120141342,
#    'no_speech_prob': 0.016911162063479424},
#   {'id': 75,
#    'seek': 32000,
#    'start': 338.64,
#    'end': 341.04,
#    'text': ' Venrock Associated. The rest is history.',
#    'tokens': [51296,
#     11182,
#     17799,
#     8619,
#     770,
#     13,
#     440,
#     1472,
#     307,
#     2503,
#     13,
#     51416],
#    'temperature': 0.0,
#    'avg_logprob': -0.13327377492731268,
#    'compression_ratio': 1.7031802120141342,
#    'no_speech_prob': 0.016911162063479424},
#   {'id': 76,
#    'seek': 32000,
#    'start': 344.48,
#    'end': 348.4,
#    'text': " To put it another way, Silicon Valley's success is not due to the fact that it has many entrepreneurs.",
#    'tokens': [51588,
#     1407,
#     829,
#     309,
#     1071,
#     636,
#     11,
#     25351,
#     10666,
#     311,
#     2245,
#     307,
#     406,
#     3462,
#     281,
#     264,
#     1186,
#     300,
#     309,
#     575,
#     867,
#     12639,
#     13,
#     51784],
#    'temperature': 0.0,
#    'avg_logprob': -0.13327377492731268,
#    'compression_ratio': 1.7031802120141342,
#    'no_speech_prob': 0.016911162063479424},
#   {'id': 77,
#    'seek': 34840,
#    'start': 348.4,
#    'end': 352.56,
#    'text': ' There are entrepreneurs everywhere. The difference is that in Silicon Valley, the conditions are',
#    'tokens': [50364,
#     821,
#     366,
#     12639,
#     5315,
#     13,
#     440,
#     2649,
#     307,
#     300,
#     294,
#     25351,
#     10666,
#     11,
#     264,
#     4487,
#     366,
#     50572],
#    'temperature': 0.0,
#    'avg_logprob': -0.0873978683371949,
#    'compression_ratio': 1.7657894736842106,
#    'no_speech_prob': 0.005301151890307665},
#   {'id': 78,
#    'seek': 34840,
#    'start': 352.56,
#    'end': 356.56,
#    'text': ' right for a company to start from scratch and end up listed on Wall Street within just a few years.',
#    'tokens': [50572,
#     558,
#     337,
#     257,
#     2237,
#     281,
#     722,
#     490,
#     8459,
#     293,
#     917,
#     493,
#     10052,
#     322,
#     9551,
#     7638,
#     1951,
#     445,
#     257,
#     1326,
#     924,
#     13,
#     50772],
#    'temperature': 0.0,
#    'avg_logprob': -0.0873978683371949,
#    'compression_ratio': 1.7657894736842106,
#    'no_speech_prob': 0.005301151890307665},
#   {'id': 79,
#    'seek': 34840,
#    'start': 356.56,
#    'end': 361.12,
#    'text': ' This is the story of Google, Facebook, Apple, and so many other companies that have changed our lives.',
#    'tokens': [50772,
#     639,
#     307,
#     264,
#     1657,
#     295,
#     3329,
#     11,
#     4384,
#     11,
#     6373,
#     11,
#     293,
#     370,
#     867,
#     661,
#     3431,
#     300,
#     362,
#     3105,
#     527,
#     2909,
#     13,
#     51000],
#    'temperature': 0.0,
#    'avg_logprob': -0.0873978683371949,
#    'compression_ratio': 1.7657894736842106,
#    'no_speech_prob': 0.005301151890307665},
#   {'id': 80,
#    'seek': 34840,
#    'start': 361.12,
#    'end': 367.12,
#    'text': ' But the question is, what does Silicon Valley have that does not exist in Europe? Flexibility comes first.',
#    'tokens': [51000,
#     583,
#     264,
#     1168,
#     307,
#     11,
#     437,
#     775,
#     25351,
#     10666,
#     362,
#     300,
#     775,
#     406,
#     2514,
#     294,
#     3315,
#     30,
#     29208,
#     2841,
#     1487,
#     700,
#     13,
#     51300],
#    'temperature': 0.0,
#    'avg_logprob': -0.0873978683371949,
#    'compression_ratio': 1.7657894736842106,
#    'no_speech_prob': 0.005301151890307665},
#   {'id': 81,
#    'seek': 34840,
#    'start': 367.12,
#    'end': 370.47999999999996,
#    'text': ' What happens if you want to work for two competing companies at the same time? No problem.',
#    'tokens': [51300,
#     708,
#     2314,
#     498,
#     291,
#     528,
#     281,
#     589,
#     337,
#     732,
#     15439,
#     3431,
#     412,
#     264,
#     912,
#     565,
#     30,
#     883,
#     1154,
#     13,
#     51468],
#    'temperature': 0.0,
#    'avg_logprob': -0.0873978683371949,
#    'compression_ratio': 1.7657894736842106,
#    'no_speech_prob': 0.005301151890307665},
#   {'id': 82,
#    'seek': 34840,
# ...
#    'start': 923.2,
#    'end': 926.72,
#    'text': ' Firstly, the development of applied research is sought. In other words, money is spent with',
#    'tokens': [51336,
#     20042,
#     11,
#     264,
#     3250,
#     295,
#     6456,
#     2132,
#     307,
#     17532,
#     13,
#     682,
#     661,
#     2283,
#     11,
#     1460,
#     307,
#     4418,
#     365,
#     51512],
#    'temperature': 0.0,
#    'avg_logprob': -0.1013652469040057,
#    'compression_ratio': 1.70446735395189,
#    'no_speech_prob': 0.02712380886077881},
#   {'id': 252,
#    'seek': 90376,
#    'start': 926.72,
#    'end': 930.48,
#    'text': ' the clear intention of creating new products and technologies to be used for specific products',
#    'tokens': [51512,
#     264,
#     1850,
#     7789,
#     295,
#     4084,
#     777,
#     3383,
#     293,
#     7943,
#     281,
#     312,
#     1143,
#     337,
#     2685,
#     3383,
#     51700],
#    'temperature': 0.0,
#    'avg_logprob': -0.1013652469040057,
#    'compression_ratio': 1.70446735395189,
#    'no_speech_prob': 0.02712380886077881},
#   {'id': 253,
#    'seek': 93048,
#    'start': 931.36,
#    'end': 934.8000000000001,
#    'text': ' and services. Secondly, military research relies on private companies and is closely linked to',
#    'tokens': [50408,
#     293,
#     3328,
#     13,
#     19483,
#     11,
#     4632,
#     2132,
#     30910,
#     322,
#     4551,
#     3431,
#     293,
#     307,
#     8185,
#     9408,
#     281,
#     50580],
#    'temperature': 0.0,
#    'avg_logprob': -0.09852894147237141,
#    'compression_ratio': 1.7770897832817338,
#    'no_speech_prob': 0.0052963923662900925},
#   {'id': 254,
#    'seek': 93048,
#    'start': 934.8000000000001,
#    'end': 939.28,
#    'text': ' industrial processes. And thirdly, the ability to export this technology is usually taken into',
#    'tokens': [50580,
#     9987,
#     7555,
#     13,
#     400,
#     2636,
#     356,
#     11,
#     264,
#     3485,
#     281,
#     10725,
#     341,
#     2899,
#     307,
#     2673,
#     2726,
#     666,
#     50804],
#    'temperature': 0.0,
#    'avg_logprob': -0.09852894147237141,
#    'compression_ratio': 1.7770897832817338,
#    'no_speech_prob': 0.0052963923662900925},
#   {'id': 255,
#    'seek': 93048,
#    'start': 939.28,
#    'end': 943.12,
#    'text': ' account. This is because the military industrial process is very capital intensive and for a new',
#    'tokens': [50804,
#     2696,
#     13,
#     639,
#     307,
#     570,
#     264,
#     4632,
#     9987,
#     1399,
#     307,
#     588,
#     4238,
#     18957,
#     293,
#     337,
#     257,
#     777,
#     50996],
#    'temperature': 0.0,
#    'avg_logprob': -0.09852894147237141,
#    'compression_ratio': 1.7770897832817338,
#    'no_speech_prob': 0.0052963923662900925},
#   {'id': 256,
#    'seek': 93048,
#    'start': 943.12,
#    'end': 946.72,
#    'text': ' development to be profitable, it usually needs to be mass-produced. Well, these three major',
#    'tokens': [50996,
#     3250,
#     281,
#     312,
#     21608,
#     11,
#     309,
#     2673,
#     2203,
#     281,
#     312,
#     2758,
#     12,
#     14314,
#     1232,
#     13,
#     1042,
#     11,
#     613,
#     1045,
#     2563,
#     51176],
#    'temperature': 0.0,
#    'avg_logprob': -0.09852894147237141,
#    'compression_ratio': 1.7770897832817338,
#    'no_speech_prob': 0.0052963923662900925},
#   {'id': 257,
#    'seek': 93048,
#    'start': 946.72,
#    'end': 950.48,
#    'text': ' advantages mean that military spending tends to be relatively efficient, at least more so than',
#    'tokens': [51176,
#     14906,
#     914,
#     300,
#     4632,
#     6434,
#     12258,
#     281,
#     312,
#     7226,
#     7148,
#     11,
#     412,
#     1935,
#     544,
#     370,
#     813,
#     51364],
#    'temperature': 0.0,
#    'avg_logprob': -0.09852894147237141,
#    'compression_ratio': 1.7770897832817338,
#    'no_speech_prob': 0.0052963923662900925},
#   {'id': 258,
#    'seek': 93048,
#    'start': 950.48,
#    'end': 954.48,
#    'text': ' other types of spending when it comes to boosting a technology industry. Of course, it is not enough',
#    'tokens': [51364,
#     661,
#     3467,
#     295,
#     6434,
#     562,
#     309,
#     1487,
#     281,
#     43117,
#     257,
#     2899,
#     3518,
#     13,
#     2720,
#     1164,
#     11,
#     309,
#     307,
#     406,
#     1547,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.09852894147237141,
#    'compression_ratio': 1.7770897832817338,
#    'no_speech_prob': 0.0052963923662900925},
#   {'id': 259,
#    'seek': 95448,
#    'start': 954.5600000000001,
#    'end': 962.4,
#    'text': ' on its own, more is needed. But what needs to change in Europe for all this money to be translated',
#    'tokens': [50368,
#     322,
#     1080,
#     1065,
#     11,
#     544,
#     307,
#     2978,
#     13,
#     583,
#     437,
#     2203,
#     281,
#     1319,
#     294,
#     3315,
#     337,
#     439,
#     341,
#     1460,
#     281,
#     312,
#     16805,
#     50760],
#    'temperature': 0.0,
#    'avg_logprob': -0.1217852863696737,
#    'compression_ratio': 1.6120401337792643,
#    'no_speech_prob': 0.010476809926331043},
#   {'id': 260,
#    'seek': 95448,
#    'start': 962.4,
#    'end': 972.72,
#    'text': ' into innovative companies? Mainly, two elements are needed. Firstly, it is important that the states',
#    'tokens': [50760,
#     666,
#     12999,
#     3431,
#     30,
#     47468,
#     11,
#     732,
#     4959,
#     366,
#     2978,
#     13,
#     20042,
#     11,
#     309,
#     307,
#     1021,
#     300,
#     264,
#     4368,
#     51276],
#    'temperature': 0.0,
#    'avg_logprob': -0.1217852863696737,
#    'compression_ratio': 1.6120401337792643,
#    'no_speech_prob': 0.010476809926331043},
#   {'id': 261,
#    'seek': 95448,
#    'start': 972.72,
#    'end': 976.48,
#    'text': " are willing to cooperate in defence, and that is not easy. Let's give an example. Imagine that",
#    'tokens': [51276,
#     366,
#     4950,
#     281,
#     26667,
#     294,
#     25913,
#     11,
#     293,
#     300,
#     307,
#     406,
#     1858,
#     13,
#     961,
#     311,
#     976,
#     364,
#     1365,
#     13,
#     11739,
#     300,
#     51464],
#    'temperature': 0.0,
#    'avg_logprob': -0.1217852863696737,
#    'compression_ratio': 1.6120401337792643,
#    'no_speech_prob': 0.010476809926331043},
#   {'id': 262,
#    'seek': 95448,
#    'start': 976.48,
#    'end': 980.48,
#    'text': ' Spain, France and Italy got together to develop an artificial intelligence project. Where will',
#    'tokens': [51464,
#     12838,
#     11,
#     6190,
#     293,
#     10705,
#     658,
#     1214,
#     281,
#     1499,
#     364,
#     11677,
#     7599,
#     1716,
#     13,
#     2305,
#     486,
#     51664],
#    'temperature': 0.0,
#    'avg_logprob': -0.1217852863696737,
#    'compression_ratio': 1.6120401337792643,
#    'no_speech_prob': 0.010476809926331043},
#   {'id': 263,
#    'seek': 95448,
#    'start': 980.48,
#    'end': 984.08,
#    'text': ' the factory be set up? Which university will do most of the research? Would France really be',
#    'tokens': [51664,
#     264,
#     9265,
#     312,
#     992,
#     493,
#     30,
#     3013,
#     5454,
#     486,
#     360,
#     881,
#     295,
#     264,
#     2132,
#     30,
#     6068,
#     6190,
#     534,
#     312,
#     51844],
#    'temperature': 0.0,
#    'avg_logprob': -0.1217852863696737,
#    'compression_ratio': 1.6120401337792643,
#    'no_speech_prob': 0.010476809926331043},
#   {'id': 264,
#    'seek': 98408,
#    'start': 984.08,
#    'end': 987.9200000000001,
#    'text': ' willing to pay to finance a project that will create jobs in another country? These kinds of',
#    'tokens': [50364,
#     4950,
#     281,
#     1689,
#     281,
#     10719,
#     257,
#     1716,
#     300,
#     486,
#     1884,
#     4782,
#     294,
#     1071,
#     1941,
#     30,
#     1981,
#     3685,
#     295,
#     50556],
#    'temperature': 0.0,
#    'avg_logprob': -0.10381161755528943,
#    'compression_ratio': 1.6474164133738602,
#    'no_speech_prob': 0.004603736102581024},
#   {'id': 265,
#    'seek': 98408,
#    'start': 987.9200000000001,
#    'end': 993.0400000000001,
#    'text': ' discussions can delay projects for years, and they end up generating all sorts of cost overruns.',
#    'tokens': [50556,
#     11088,
#     393,
#     8577,
#     4455,
#     337,
#     924,
#     11,
#     293,
#     436,
#     917,
#     493,
#     17746,
#     439,
#     7527,
#     295,
#     2063,
#     670,
#     12997,
#     82,
#     13,
#     50812],
#    'temperature': 0.0,
#    'avg_logprob': -0.10381161755528943,
#    'compression_ratio': 1.6474164133738602,
#    'no_speech_prob': 0.004603736102581024},
#   {'id': 266,
#    'seek': 98408,
#    'start': 993.0400000000001,
#    'end': 997.12,
#    'text': ' Secondly, it is essential for universities to be able to participate in defence projects. European',
#    'tokens': [50812,
#     19483,
#     11,
#     309,
#     307,
#     7115,
#     337,
#     11779,
#     281,
#     312,
#     1075,
#     281,
#     8197,
#     294,
#     25913,
#     4455,
#     13,
#     6473,
#     51016],
#    'temperature': 0.0,
#    'avg_logprob': -0.10381161755528943,
#    'compression_ratio': 1.6474164133738602,
#    'no_speech_prob': 0.004603736102581024},
#   {'id': 267,
#    'seek': 98408,
#    'start': 997.12,
#    'end': 999.44,
#    'text': ' universities have to get used to working with private companies.',
#    'tokens': [51016,
#     11779,
#     362,
#     281,
#     483,
#     1143,
#     281,
#     1364,
#     365,
#     4551,
#     3431,
#     13,
#     51132],
#    'temperature': 0.0,
#    'avg_logprob': -0.10381161755528943,
#    'compression_ratio': 1.6474164133738602,
#    'no_speech_prob': 0.004603736102581024},
#   {'id': 268,
#    'seek': 98408,
#    'start': 1003.44,
#    'end': 1007.44,
#    'text': ' And thirdly, Europe needs to relax many of the regulations that currently hinder this type of',
#    'tokens': [51332,
#     400,
#     2636,
#     356,
#     11,
#     3315,
#     2203,
#     281,
#     5789,
#     867,
#     295,
#     264,
#     12563,
#     300,
#     4362,
#     276,
#     5669,
#     341,
#     2010,
#     295,
#     51532],
#    'temperature': 0.0,
#    'avg_logprob': -0.10381161755528943,
#    'compression_ratio': 1.6474164133738602,
#    'no_speech_prob': 0.004603736102581024},
#   {'id': 269,
#    'seek': 98408,
#    'start': 1007.44,
#    'end': 1012.08,
#    'text': ' activity. One idea could be create a special economic zone following the model proposed by Liz',
#    'tokens': [51532,
#     5191,
#     13,
#     1485,
#     1558,
#     727,
#     312,
#     1884,
#     257,
#     2121,
#     4836,
#     6668,
#     3480,
#     264,
#     2316,
#     10348,
#     538,
#     16480,
#     51764],
#    'temperature': 0.0,
#    'avg_logprob': -0.10381161755528943,
#    'compression_ratio': 1.6474164133738602,
#    'no_speech_prob': 0.004603736102581024},
#   {'id': 270,
#    'seek': 101208,
#    'start': 1012.1600000000001,
#    'end': 1016.5600000000001,
#    'text': ' Trust in the United Kingdom. Economic zones where urban planning rules, business rules or taxes',
#    'tokens': [50368,
#     11580,
#     294,
#     264,
#     2824,
#     11277,
#     13,
#     25776,
#     16025,
#     689,
#     9681,
#     5038,
#     4474,
#     11,
#     1606,
#     4474,
#     420,
#     10041,
#     50588],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 271,
#    'seek': 101208,
#    'start': 1016.5600000000001,
#    'end': 1020.4000000000001,
#    'text': ' are relaxed or better adapted to the reality of this industry. This could make it possible to turn',
#    'tokens': [50588,
#     366,
#     14628,
#     420,
#     1101,
#     20871,
#     281,
#     264,
#     4103,
#     295,
#     341,
#     3518,
#     13,
#     639,
#     727,
#     652,
#     309,
#     1944,
#     281,
#     1261,
#     50780],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 272,
#    'seek': 101208,
#    'start': 1020.4000000000001,
#    'end': 1023.0400000000001,
#    'text': " the military race into a new Silicon Valley's threat to Europe.",
#    'tokens': [50780,
#     264,
#     4632,
#     4569,
#     666,
#     257,
#     777,
#     25351,
#     10666,
#     311,
#     4734,
#     281,
#     3315,
#     13,
#     50912],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 273,
#    'seek': 101208,
#    'start': 1025.52,
#    'end': 1029.1200000000001,
#    'text': " Now the questions though are over to you. Will Europe see a Silicon Valley or will Europe's",
#    'tokens': [51036,
#     823,
#     264,
#     1651,
#     1673,
#     366,
#     670,
#     281,
#     291,
#     13,
#     3099,
#     3315,
#     536,
#     257,
#     25351,
#     10666,
#     420,
#     486,
#     3315,
#     311,
#     51216],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 274,
#    'seek': 101208,
#    'start': 1029.1200000000001,
#    'end': 1032.88,
#    'text': ' declarations just fine words? Will this compensate for the loss of competitiveness due to higher',
#    'tokens': [51216,
#     16694,
#     763,
#     445,
#     2489,
#     2283,
#     30,
#     3099,
#     341,
#     29458,
#     337,
#     264,
#     4470,
#     295,
#     41131,
#     8477,
#     3462,
#     281,
#     2946,
#     51404],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 275,
#    'seek': 101208,
#    'start': 1032.88,
#    'end': 1036.88,
#    'text': " energy prices? Will the European Union manage to avoid having several many Silicon Valley's,",
#    'tokens': [51404,
#     2281,
#     7901,
#     30,
#     3099,
#     264,
#     6473,
#     8133,
#     3067,
#     281,
#     5042,
#     1419,
#     2940,
#     867,
#     25351,
#     10666,
#     311,
#     11,
#     51604],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 276,
#    'seek': 101208,
#    'start': 1036.88,
#    'end': 1041.3600000000001,
#    'text': ' or will it end up becoming a gigantic a destroyed instead? You can leave me your answers in the comments',
#    'tokens': [51604,
#     420,
#     486,
#     309,
#     917,
#     493,
#     5617,
#     257,
#     26800,
#     257,
#     8937,
#     2602,
#     30,
#     509,
#     393,
#     1856,
#     385,
#     428,
#     6338,
#     294,
#     264,
#     3053,
#     51828],
#    'temperature': 0.0,
#    'avg_logprob': -0.1762791633605957,
#    'compression_ratio': 1.7245989304812834,
#    'no_speech_prob': 0.03453787788748741},
#   {'id': 277,
#    'seek': 104136,
#    'start': 1041.36,
#    'end': 1043.36,
#    'text': " below. As always, don't forget that here on Visual",
#    'tokens': [50364,
#     2507,
#     13,
#     1018,
#     1009,
#     11,
#     500,
#     380,
#     2870,
#     300,
#     510,
#     322,
#     23187,
#     50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.20865038821571752,
#    'compression_ratio': 1.4845360824742269,
#    'no_speech_prob': 0.019707640632987022},
#   {'id': 278,
#    'seek': 104136,
#    'start': 1043.36,
#    'end': 1046.6399999999999,
#    'text': ' Politics we release new videos every week, so subscribe to this channel and hit the little bell',
#    'tokens': [50464,
#     45348,
#     321,
#     4374,
#     777,
#     2145,
#     633,
#     1243,
#     11,
#     370,
#     3022,
#     281,
#     341,
#     2269,
#     293,
#     2045,
#     264,
#     707,
#     4549,
#     50628],
#    'temperature': 0.0,
#    'avg_logprob': -0.20865038821571752,
#    'compression_ratio': 1.4845360824742269,
#    'no_speech_prob': 0.019707640632987022},
#   {'id': 279,
#    'seek': 104136,
#    'start': 1046.6399999999999,
#    'end': 1050.08,
#    'text': " button down there so you don't miss any of our updates. If you like this video, like it.",
#    'tokens': [50628,
#     2960,
#     760,
#     456,
#     370,
#     291,
#     500,
#     380,
#     1713,
#     604,
#     295,
#     527,
#     9205,
#     13,
#     759,
#     291,
#     411,
#     341,
#     960,
#     11,
#     411,
#     309,
#     13,
#     50800],
#    'temperature': 0.0,
#    'avg_logprob': -0.20865038821571752,
#    'compression_ratio': 1.4845360824742269,
#    'no_speech_prob': 0.019707640632987022},
#   {'id': 280,
#    'seek': 104136,
#    'start': 1050.08,
#    'end': 1061.9199999999998,
#    'text': " So we know all the best, and I'll see you next time.",
#    'tokens': [50800,
#     407,
#     321,
#     458,
#     439,
#     264,
#     1151,
#     11,
#     293,
#     286,
#     603,
#     536,
#     291,
#     958,
#     565,
#     13,
#     51392],
#    'temperature': 0.0,
#    'avg_logprob': -0.20865038821571752,
#    'compression_ratio': 1.4845360824742269,
#    'no_speech_prob': 0.019707640632987022}],
#  'language': 'en'}

# %% [markdown]
# Print transcription

# %%
# Print the transcription
print(output["text"])
# Out:
#  This video has been made possible by Brilliant, a problem-solving based website and app with hands-on approach. Improve your STEM skills while having a great time learning at brilliant.org for a slasher visual politic EN. More on that in a bit. Here is the million dollar question in Europe. Why is there no European Google? Why does Europe seem to be an elephant's graveyard when it comes to business? To give you an idea of the five largest companies in the world, four are American and were launched after 1975. In Europe, however, it is common for the largest companies to have been started much earlier. Some, such as Nestle, date back to the 19th century, and even the pharmaceutical companies that created a giant like Novartis were started in the 17th and 18th centuries, no less. Let's see, credit where credit's due, these companies deserve a round of applause for having managed to survive in the market. But it's significant that no young European company is in this top five while in the 90's states, three of the five largest companies are younger than many of you watching this video. This indicates one thing. The USA is way ahead of Europe in terms of innovation. This does not mean that there are no companies in Europe that have not been innovative. SAP, which is a programme used by accountants in large companies, are Skype, which we all know, were conceived in Germany and Estonia. But they aren't much when compared to the United States. Until now, this was one more debate among many in Europe. But now, it is the most important debate that will be raised in the coming years. And that is because of the energy crisis. The current crisis is affecting all citizens with stratospheric electricity bills. But do you know who else is affected by these price increases? You guessed, if visual politics viewers, the companies, many of which may flee from a dying European Union, that no longer offers them low-cost gas. The European Union is no longer more competitive than the United States or China. In a few years' time, we could be talking about the European Union as a continental Detroit. In fact, as was the case in Detroit, the automotive industry is extremely important throughout Europe and not only in France and Germany. In Spain, for example, the automotive industry accounted for almost 8% of the entire GDP in 2020. In other words, the comparison with Detroit is no joke. And if you are a loyal follower to this channel, you will already know what it means to be Detroit, unemployment, slums and cranes. So how can this trend be changed? How could Europe move closer to the Silicon Valley model? Could the war in Ukraine revive the European Union? Today we're going to answer all these questions. But before we continue, whether you're trying to develop your professional skills or broaden your understanding of the world, we recommend checking out today's sponsor, Brilliant. Brilliant is a problem-solving based website and app with a hands-on approach. It's a better way to learn. They've got over 70 interactive courses in maths, science and computer science, and it doesn't matter whether you're a student looking to get ahead, or a professional keen on building new skills. You have to check out Brilliant. It's excellent. Maybe you've always wanted to learn about statistics, and trust me, statistics can be tricky and lead you to dubious conclusions. And no, just in case you were wondering, the fact that one out every five babies born on earth or Chinese does not mean that your fifth child will be Chinese. But jokes aside, there are lots of great stuff on their platform, including daily challenges which are a great way to flex our grey matter every day. So don't wait any longer, and let Brilliant help you master even complex technical subjects by clicking on the link below. You'll get started for free and hurry. The first 200 people get 20% off an annual premium subscription. And now, let's get cracking. History of Two Places A visual politic had ...

# %%
# Save the transcription to a file
transcript_filename = "transcript_{}.txt".format(filename)
with open(transcript_filename, "w") as transcript_file:
    transcript_file.write(output["text"])

# %%
with open(transcript_filename, "r") as f:
    text = f.read()

# %% [markdown]
# ### Use text extracted from YouTube audio track as ChatGPT context

# %%
#Importing OpenAI module
try:
  import openai
except:
  # !pip install openai
  import openai

# %% [markdown]
# You can find your secret API key in your [OpenAI User Settings](https://platform.openai.com/account/api-keys).
#
# Please check [pricing for OpenAI language models](https://openai.com/pricing). For GPT-3.5 (ChatGPT) model, it is currently around $0.003 for 1K tokens (750 words).

# %%
## API Key
## Store your key in file api_key.txt and read it
## Alternatlively, you can copy/paste your key directly as
## API_KEY = "sk-BV9ZRsx7b7GHHtLS9CslT3BlbkFNNeCVWZMluYw2y8AIZ9HY"
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    f = open("drive/MyDrive/files/api_key.txt", "r")
    API_KEY=f.readline()
    f.close()
else:
    f = open("api_key.txt", "r")
    API_KEY=f.readline()
    f.close()

# OpenAI Key
import os
os.environ['OPENAI_API_KEY'] = API_KEY
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# OpenAI API parameters
model = "gpt-3.5-turbo-16k"
# model = "gpt-3.5-turbo" # 4K tokens
# model = "gpt-4"
max_tokens = 1024
n = 1
stop = None
temperature = 0.5

# %% [markdown]
# ### Prompt 1 - ChatGPT generating text for a Facebook post

# %%
prompt_1 = 'Please write a three sentence Facebook post in Ukrainian language about how Ukraine can innovate based on the following relevant transcript: "{input}"'

# %%
prompt1   = prompt_1.format(input=text)
response1 = openai.ChatCompletion.create(
    model=model,
    messages=[
    {"role": "system", "content": "You are a helpful  assistant."},
    {"role": "user", "content": prompt1},
    ],
    max_tokens=max_tokens,
    n=n,
    stop=stop,
    temperature=temperature,
)

# %%
coutput1 = response1['choices'][0]['message']['content']
print(coutput1)
# Out:
# Україна має потенціал для інноваційного розвитку, якщо врахувати фактори, що сприяють успіху в інших країнах. Наприклад, Silicon Valley в США став ключовим центром інновацій через гнучкість, співпрацю університетів з приватними компаніями та наявність венчурного капіталу. Європейські країни також мають свої успішні інноваційні компанії, але для досягнення великих результатів потрібно зменшити регулятивні обмеження і сприяти співпраці між університетами та приватним сектором. Криза в Україні може стати каталізатором для змін і сприяти розвитку інноваційного потенціалу країни.

# %% [markdown]
# ### Prompt 2 - ChatGPT generating text about innovation in Canada

# %%
prompt_2 = "Innovations in different countries are based on a number of factors. Here is the relevant transacript. Please write five steps how Ukraine can innovate: {input}"

# %%
prompt2   = prompt_2.format(input=text)
response2 = openai.ChatCompletion.create(
    model=model,
    messages=[
    {"role": "system", "content": "You are a helpful  assistant."},
    {"role": "user", "content": prompt2},
    ],
    max_tokens=max_tokens,
    n=n,
    stop=stop,
    temperature=temperature,
)

# %%
coutput2 = response2['choices'][0]['message']['content']
print(coutput2)
# Out:
# To foster innovation in Ukraine, the following steps can be taken:
#
# 1. Foster collaboration between universities and private enterprises: Ukraine can take inspiration from the Silicon Valley model and encourage universities to collaborate with private companies. This can be done by creating partnerships, funding research projects, and providing resources for innovation.
#
# 2. Create a favorable regulatory environment: Ukraine should work on reducing bureaucratic hurdles and regulations that hinder innovation. Streamlining processes and creating special economic zones with relaxed rules can attract more investment and encourage entrepreneurship.
#
# 3. Increase investment in research and development: The government should allocate more funds towards research and development activities. This can be done through grants, tax incentives, and public-private partnerships. Investing in R&D will help Ukraine develop new technologies and products.
#
# 4. Promote entrepreneurship and startup culture: Ukraine can create programs and initiatives to support and nurture startups. This can include providing mentorship, access to funding, and networking opportunities. Encouraging entrepreneurship will foster a culture of innovation and creativity.
#
# 5. Develop a skilled workforce: Ukraine should focus on improving STEM education and training programs. By investing in the development of a skilled workforce, the country can attract more tech companies and promote innovation in various sectors.
#
# By implementing these steps, Ukraine can create an environment that fosters innovation and supports the growth of startups and tech companies.

# %% [markdown]
# ### Prompt 3 - ChatGPT summarizing text

# %%
prompt_3 = "Summarize the following text: {input}"

# %%
prompt3   = prompt_3.format(input=text)
response3 = openai.ChatCompletion.create(
    model=model,
    messages=[
    {"role": "system", "content": "You are a helpful  assistant."},
    {"role": "user", "content": prompt3},
    ],
    max_tokens=max_tokens,
    n=n,
    stop=stop,
    temperature=temperature,
)

# %%
coutput3 = response3['choices'][0]['message']['content']
print(coutput3)
# Out:
# The text discusses the lack of a European Google and the innovation gap between Europe and the United States. It highlights the historical success of Silicon Valley and the decline of Detroit, and explores the factors that contribute to innovation in Silicon Valley, such as flexibility, university-industry collaboration, and venture capital. The text also mentions the challenges faced by Europe in terms of regulations, lack of investment in military technology, and limited collaboration between European countries. It suggests that the war in Ukraine and increased military spending could potentially spur innovation and the development of a European Silicon Valley. However, it also raises questions about whether Europe will be able to overcome its challenges and become competitive in the global market.

# %% [markdown]
# ### Text-to-speech for ChatGPT generate sumamry

# %%
#Importing gTTS
try:
  from gtts import gTTS
except:
  # !pip install gTTS
  from gtts import gTTS

# %%
from gtts import gTTS
tts = gTTS(coutput3)
tts.save('chatgpt_summary.wav')

# %%
from IPython.display import Audio
sound_file = 'chatgpt_summary.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
